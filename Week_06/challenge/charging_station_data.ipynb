# %% [markdown]
# # Charging stations for electric vehicles

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import re
import json
import folium
import pandas as pd
import matplotlib.pyplot as plt
from urllib.request import urlopen

# Background color of graphics
# plt.style.use('dark_background')

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Show current working directory
print(os.getcwd())
# Out:
# u:\Lektionen\Scientific_Programming_FS2023\scientific_programming\Week_06\challenge

# %% [markdown]
# ### Request charging station data

# %%
# Url for server request
url = "https://upload.geo.admin.ch/ch.bfe.ladestellen-elektromobilitaet/data/oicp/ch.bfe.ladestellen-elektromobilitaet.json"
  
# Request data from server
response = urlopen(url)
  
# Load data
data_orig = json.loads(response.read())

# Save the data as pandas data frame
data = pd.DataFrame(data_orig["EVSEData"])
data
# Out:
#                                        EVSEDataRecord          OperatorID  \
# 0   [{'Address': {'City': 'Davos', 'Country': 'CHE...              CH*EWD
# 1   [{'Address': {'City': 'Dietikon', 'Country': '...              CH*TES
# 2   [{'Address': {'City': 'Herrliberg', 'Country':...              CH*HER
# 3   [{'Address': {'City': 'Interlaken', 'Country':...              CH*BVS
# 4   [{'Address': {'City': 'Schwyz', 'Country': 'CH...              CH*EBS
# 5   [{'Address': {'City': 'Dietikon', 'Country': '...              CH*DIE
# 6   [{'Address': {'City': 'Altendorf', 'Country': ...             CH*LIDL
# 7   [{'Address': {'City': 'Sarnen', 'Country': 'CH...              CH*EWO
# 8   [{'Address': {'City': 'Niederbüren', 'Country'...             CH*AVIA
# 9   [{'Address': {'City': 'Ittigen', 'Country': 'C...              CH*ION
# 10                                                 []             CH*BGDI
# 11  [{'Address': {'City': 'Rudolfstetten', 'Countr...     CH*MOBILECHARGE
# 12  [{'Address': {'City': 'Altdorf', 'Country': 'C...        CH*EWACHARGE
# 13  [{'Address': {'City': 'Avenches', 'Country': '...              CH*CCC
# 14  [{'Address': {'City': 'Chur', 'Country': 'CHE'...              CH*ECU
# 15                                                 []              CH*IBC
# 16  [{'Address': {'City': 'Täsch', 'Country': 'CHE...              CH*TAE
# 17  [{'Address': {'City': 'Studen BE', 'Country': ...              CH*MIG
# 18  [{'Address': {'City': 'Freienbach', 'Country':...       CH*PARKCHARGE
# 19  [{'Address': {'City': 'Susten', 'Country': 'CH...   CH*ENMOBILECHARGE
# 20  [{'Address': {'City': 'Muzzano', 'Country': 'C...              CH*AIL
# 21  [{'Address': {'City': 'Winterthur', 'Country':...          CH*SCHARGE
# 22  [{'Address': {'City': 'Seewen SZ', 'Country': ...      CH*SWISSCHARGE
# 23  [{'Address': {'City': 'Buchs', 'Country': 'CHE...     CH*PACEMOBILITY
# 24  [{'Address': {'City': 'Silvaplana', 'Country':...              CH*REP
# 25  [{'Address': {'City': 'Bussigny', 'Country': '...               CHEVP
# 26  [{'Address': {'City': 'Altendorf', 'Country': ...   CH*EVAEMOBILITAET
# 27  [{'Address': {'City': 'Horgen', 'Country': 'CH...  CH*MOBIMOEMOBILITY
# 28  [{'Address': {'City': 'Suhr', 'Country': 'CHE'...          CH*FASTNED
#
#                       OperatorName
# 0   EWD Elektrizitätswerk Davos AG
# 1                            Tesla
# 2     Elektrizitätswerk Herrliberg
# 3      Backpackers Villa Sonnenhof
# 4                   ebs Energie AG
# 5                   Stadt Dietikon
# 6                     Lidl Schweiz
# 7       Elektrizitätswerk Obwalden
# 8                             AVIA
# 9                           IONITY
# 10                      Bgdi_Admin
# 11                    mobilecharge
# 12                       EWAcharge
# 13                            Move
# 14                          eCarUp
# 15                             IBC
# 16       Matterhorn Terminal Täsch
# 17            Migrol Fast Charging
# 18                   PARK & CHARGE
# 19                en mobilecharge
# 20                             AIL
# 21                        S-Charge
# 22                     Swisscharge
# 23                   PAC e-moblity
# 24                     PLUG’N ROLL
# 25                          evpass
# 26                 EVA E-Mobilität
# 27                Mobimo emobility
# 28                         Fastned

# %% [markdown]
# ### Deriving data from the operator 'evpass'

# %%
# Getting the index of evpass
idx = data[data["OperatorName"].isin(['evpass'])].index[0]
print(idx)

# Create data frame from column 'EVSEDataRecord' in the subset
df = pd.DataFrame(data.loc[idx, 'EVSEDataRecord'])
df.head()
# Out:
# 25
#                                              Address  IsOpen24Hours  \
# 0  {'City': 'Bussigny', 'Country': 'CHE', 'HouseN...          False
# 1  {'City': 'Bussigny', 'Country': 'CHE', 'HouseN...          False
# 2  {'City': 'Crans-Montana', 'Country': 'CHE', 'H...          False
# 3  {'City': 'Crans-Montana', 'Country': 'CHE', 'H...          False
# 4  {'City': 'Vandoeuvres', 'Country': 'CHE', 'Hou...          False
#
#   ChargingStationId                    GeoCoordinates lastUpdate  \
# 0                72  {'Google': '46.547745 6.552618'}       None
# 1                72  {'Google': '46.547745 6.552618'}       None
# 2                92  {'Google': '46.308936 7.471237'}       None
# 3                92  {'Google': '46.308936 7.471237'}       None
# 4               100  {'Google': '46.222434 6.203629'}       None
#
#   HotlinePhoneNum ClearinghouseID OpeningTimes GeoChargingPointEntrance  \
# 0      0488848044            None         None  {'Google': 'None None'}
# 1      0488848044            None         None  {'Google': 'None None'}
# 2      0488848044            None         None  {'Google': 'None None'}
# 3      0488848044            None         None  {'Google': 'None None'}
# 4      0488848044            None         None  {'Google': 'None None'}
#
#   HubOperatorID  ... IsHubjectCompatible MaxCapacity PaymentOptions  \
# 0          None  ...               False        None     [Contract]
# 1          None  ...               False        None     [Contract]
# 2          None  ...               False        None   [No Payment]
# 3          None  ...               False        None   [No Payment]
# 4          None  ...               False        None     [Contract]
#
#                                       AdditionalInfo ChargingPoolID deltaType  \
# 0  [{'lang': 'fr', 'value': 'Parking payant devan...           None      None
# 1  [{'lang': 'fr', 'value': 'Parking payant devan...           None      None
# 2  [{'lang': 'fr', 'value': 'Bâtiment Police muni...           None      None
# 3  [{'lang': 'fr', 'value': 'Bâtiment Police muni...           None      None
# 4                                               None           None      None
#
#        ValueAddedServices                           AuthenticationModes  \
# 0  [MaximumPowerCharging]  [REMOTE, NFC RFID Classic, NFC RFID DESFire]
# 1  [MaximumPowerCharging]  [REMOTE, NFC RFID Classic, NFC RFID DESFire]
# 2  [MaximumPowerCharging]  [REMOTE, NFC RFID Classic, NFC RFID DESFire]
# 3  [MaximumPowerCharging]  [REMOTE, NFC RFID Classic, NFC RFID DESFire]
# 4  [MaximumPowerCharging]  [REMOTE, NFC RFID Classic, NFC RFID DESFire]
#
#   DynamicPowerLevel HardwareManufacturer
# 0              None                 None
# 1              None                 None
# 2              None                 None
# 3              None                 None
# 4              None                 None
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Take a closer look at the coordinates

# %%
# Look at the geo-coordinates (latitude and longitude)
coordinates = df.GeoCoordinates
print(type(coordinates))
print(coordinates)

# Look at the type of a single item in the data frame
print(type(coordinates[0]))
# Out:
# <class 'pandas.core.series.Series'>
# 0       {'Google': '46.547745 6.552618'}
# 1       {'Google': '46.547745 6.552618'}
# 2       {'Google': '46.308936 7.471237'}
# 3       {'Google': '46.308936 7.471237'}
# 4       {'Google': '46.222434 6.203629'}
#                       ...
# 2706     {'Google': '46.02042 8.983383'}
# 2707     {'Google': '46.02042 8.983383'}
# 2708    {'Google': '45.974368 8.873363'}
# 2709    {'Google': '45.974368 8.873363'}
# 2710    {'Google': '46.513252 6.677504'}
# Name: GeoCoordinates, Length: 2711, dtype: object
# <class 'dict'>

# %% [markdown]
# ### Extracting the latitude and longitude

# %%
# Getting single values from as string
coord_str = "".join(coordinates[0].values())
coord_str 

# Splitting string by white space
re.findall(r'\S+', coord_str)
# Out:
# ['46.547745', '6.552618']

# %% [markdown]
# ### Using a for loop to write the latitude and longitude to a separate data frame

# %%
# Now loop though the coordinates object
out_list = []

for i in coordinates:
    # Getting single values from as string
    coord_str = "".join(i.values())
    # Splitting string by white space
    coords = re.findall(r'\S+', coord_str)
    out_list.append(coords)

# Create data frame from the list
df = pd.DataFrame(out_list, columns =['lat', 'lon'])
print(df.dtypes)

# Here we still have strings which need to be converted to integers

# First: exclude white space using pythons lambda function
df['lat'] = df['lat'].apply(lambda x: x.strip())
df['lon'] = df['lon'].apply(lambda x: x.strip())

# Second: cange to integer values
df['lat'] = df['lat'].astype(float)
df['lon'] =  df['lon'].astype(float)
df
# Out:
# lat    object
# lon    object
# dtype: object
#             lat       lon
# 0     46.547745  6.552618
# 1     46.547745  6.552618
# 2     46.308936  7.471237
# 3     46.308936  7.471237
# 4     46.222434  6.203629
# ...         ...       ...
# 2706  46.020420  8.983383
# 2707  46.020420  8.983383
# 2708  45.974368  8.873363
# 2709  45.974368  8.873363
# 2710  46.513252  6.677504
#
# [2711 rows x 2 columns]

# %% [markdown]
# ### Plot the charging stations of the operator 'evepass'

# %%
# Subset of gas stations by brand
locations = df[["lat", "lon"]]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]]).add_to(map)

# Plot map
map
# Out:
#          lat       lon
# 0  46.547745  6.552618
# 1  46.547745  6.552618
# 2  46.308936  7.471237
# 3  46.308936  7.471237
# 4  46.222434  6.203629
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_23b830af385fb1464e0cb1a023ec4515 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_23b830af385fb1464e0cb1a023ec4515&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_23b830af385fb1464e0cb1a023ec4515 = L.map(
#                 &quot;map_23b830af385fb1464e0cb1a023ec4515&quot;,
#                 {
#                     center: [46.62814658539284, 7.688793405385466],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#
#
#
#             var tile_layer_d53f66f221576e9c1725a19bb4989a7d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             var marker_7e7cce905708bf729d03e76d1976b7e0 = L.marker(
#                 [46.547745, 6.552618],
#                 {}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             var marker_48656a8a1041f80ffbc6f435e3a07411 = L.marker(
#                 [46.547745, 6.552618],
#                 {}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             var marker_7641b0f3f1a5d4c9372e85b4cde3bf85 = L.marker(
#                 [46.308936, 7.471237],
#                 {}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             var marker_9e5f3e5ae305f4ba0113ff5c97c4d038 = L.marker(
#                 [46.308936, 7.471237],
#                 {}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             var marker_81fdd6b871703a4daa8d14dba01c6459 = L.marker(
#                 [46.222434, 6.203629],
#                 {}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             var marker_ab2bd9e1d56d8955e568f4886ec2d035 = L.marker(
#                 [46.222434, 6.203629],
#                 {}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             var marker_261c39591e4bb68c013a4f623337b2d3 = L.marker(
#                 [46.986632, 6.915839],
#                 {}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             var marker_bc1b0866f8a7fd413aa681a2d7a1a738 = L.marker(
#                 [46.986632, 6.915839],
#                 {}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             var marker_d43db1e632bbf4173c0b88d61a522827 = L.marker(
#                 [46.233099, 7.357062],
#                 {}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             var marker_3770e32bfd38a6b036ebe40b1be1e7a6 = L.marker(
#                 [46.233099, 7.357062],
#                 {}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             var marker_498beb913df22793083c28183d112978 = L.marker(
#                 [46.233099, 7.357062],
#                 {}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             var marker_831f92d44ce01b1047c66e4d1c18e85d = L.marker(
#                 [46.233099, 7.357062],
#                 {}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             var marker_cdf79425cf6ea0b1c329f0116bbd10ae = L.marker(
#                 [46.233099, 7.357062],
#                 {}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             var marker_04099276fd1610d4833f2c2869447b14 = L.marker(
#                 [46.233099, 7.357062],
#                 {}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             var marker_ab218a5e2920ca3dd2b29dfd42ff4786 = L.marker(
#                 [46.233099, 7.357062],
#                 {}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             var marker_6614da5b2d32ac973c356968f7825a77 = L.marker(
#                 [46.991985, 6.932756],
#                 {}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             var marker_c3e19f27613e4af76bab6ca6ccfce338 = L.marker(
#                 [46.991985, 6.932756],
#                 {}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             var marker_9b4bb20514e828ccdc892cc25ea24e76 = L.marker(
#                 [46.294224, 7.535042],
#                 {}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             var marker_6291d76ca7422d59218e42ab089d3370 = L.marker(
#                 [46.294224, 7.535042],
#                 {}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             var marker_8e6da82f7a5aa1f6b2cd447d0f57fde9 = L.marker(
#                 [46.105442, 7.080599],
#                 {}
#             ).addTo(map_23b830af385fb1464e0cb1a023ec4515);
#
#
#             va

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 10
# Datetime: 2023-03-29 12:37:49
# Python Version: 3.10.9
# -----------------------------------
