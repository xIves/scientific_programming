# %% [markdown]
# # Getting all available Swiss petrol stations using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import json
import folium
import requests
import pandas as pd

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Show current working directory
print(os.getcwd())
# Out:
# u:\Lektionen\Scientific_Programming_FS2023\scientific_programming\Week_04\challenge

# %% [markdown]
# ## Overpass turbo query to get available petrol stations

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["amenity"="fuel"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to .json file
with open('petrol_stations.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = pd.json_normalize(data)
df.head()
# Out:
#    type       id        lat       lon tags.amenity  \
# 0  node   734402  46.690599  7.668189         fuel
# 1  node  1228781  46.878598  7.542326         fuel
# 2  node  5702030  46.680546  7.827412         fuel
# 3  node  5702071  46.683415  7.844559         fuel
# 4  node  8082505  46.683817  7.664427         fuel
#
#                                           tags.fixme tags.name tags.operator  \
# 0  Please check name and brand. Agip becomes Eni....      Agip          Agip
# 1                                                NaN       NaN            BP
# 2                                                NaN    Migrol           NaN
# 3                                                NaN      Avia          Avia
# 4                                                NaN       NaN           NaN
#
#   tags.brand tags.fuel:diesel  ... tags.fuel:octane_87  \
# 0        NaN              NaN  ...                 NaN
# 1         BP              yes  ...                 NaN
# 2        NaN              NaN  ...                 NaN
# 3       Avia              NaN  ...                 NaN
# 4        NaN              NaN  ...                 NaN
#
#   tags.payment:post_finance tags.payment:reka_card tags.payment:shell  \
# 0                       NaN                    NaN                NaN
# 1                       NaN                    NaN                NaN
# 2                       NaN                    NaN                NaN
# 3                       NaN                    NaN                NaN
# 4                       NaN                    NaN                NaN
#
#   tags.covered tags.payment:girocard tags.fuel:diesel_plus tags.construction  \
# 0          NaN                   NaN                   NaN               NaN
# 1          NaN                   NaN                   NaN               NaN
# 2          NaN                   NaN                   NaN               NaN
# 3          NaN                   NaN                   NaN               NaN
# 4          NaN                   NaN                   NaN               NaN
#
#   tags.payment:tamoil_card tags.dog
# 0                      NaN      NaN
# 1                      NaN      NaN
# 2                      NaN      NaN
# 3                      NaN      NaN
# 4                      NaN      NaN
#
# [5 rows x 183 columns]

# %% [markdown]
# ## Save data frame to a .csv file

# %%
# Write data frame to .csv - file
df.to_csv('petrol-stations.csv', index=False, sep=";", encoding='utf-8')

# %% [markdown]
# ## Use a pivot table to count the number of petrol stations per operator

# %%
# Create pivot table
tab = pd.pivot_table(df[['id', 'tags.name']], 
                       values=['id'], 
                       index=['tags.name'],
                       aggfunc='count')

# Sort pivot table
tab_sorted = tab.sort_values(by=['id'], ascending=False)
tab_sorted
# Out:
#                          id
# tags.name
# Avia                    154
# Agrola                  135
# BP                      108
# Tamoil                   93
# Shell                    72
# ...                     ...
# Garage des 3 Sapins       1
# Garage des Alpes          1
# Garage du Clos            1
# Garage du Gros-de-Vaud    1
# villoel                   1
#
# [820 rows x 1 columns]

# %% [markdown]
# ## Plot petrol stations on map

# %%
# Subset of petrol stations by brand
locations = df[["lat", 
                "lon", 
                "tags.brand", 
                "tags.shop"]].loc[df["tags.brand"].isin(['Migrol', 
                                                         'Agip', 
                                                         'Shell'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                   popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#           lat       lon tags.brand tags.shop
# 10  47.686119  8.621418      Shell       NaN
# 21  47.495696  8.712981      Shell       NaN
# 25  47.381554  8.509567      Shell       NaN
# 30  47.381110  8.492148     Migrol       NaN
# 34  47.337365  8.530193      Shell       NaN
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc1399c8a07567f01f01b94e1dbe2969 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc1399c8a07567f01f01b94e1dbe2969&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc1399c8a07567f01f01b94e1dbe2969 = L.map(
#                 &quot;map_fc1399c8a07567f01f01b94e1dbe2969&quot;,
#                 {
#                     center: [47.07107087855072, 8.186368940289855],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_fc1399c8a07567f01f01b94e1dbe2969);
#
#
#
#
#
#             var tile_layer_6a8c66ef80c86ca04af4bea79726c579 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fc1399c8a07567f01f01b94e1dbe2969);
#
#
#             var marker_c6098abe11620fcd47534228996f2971 = L.marker(
#                 [47.686119, 8.621418],
#                 {}
#             ).addTo(map_fc1399c8a07567f01f01b94e1dbe2969);
#
#
#         var popup_60e0653922c303f58b1e3a24d3380c71 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1c248ec0854840f3cec045787ad369a2 = $(`&lt;div id=&quot;html_1c248ec0854840f3cec045787ad369a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_60e0653922c303f58b1e3a24d3380c71.setContent(html_1c248ec0854840f3cec045787ad369a2);
#
#
#
#         marker_c6098abe11620fcd47534228996f2971.bindPopup(popup_60e0653922c303f58b1e3a24d3380c71)
#         ;
#
#
#
#
#             var marker_a5351baf9787d9b72c2afe22c0bb37fc = L.marker(
#                 [47.4956958, 8.7129812],
#                 {}
#             ).addTo(map_fc1399c8a07567f01f01b94e1dbe2969);
#
#
#         var popup_60b91a9246edab8c3f0e0bd999e33932 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_43b62d0b03401a817bc5483b50ca24b4 = $(`&lt;div id=&quot;html_43b62d0b03401a817bc5483b50ca24b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_60b91a9246edab8c3f0e0bd999e33932.setContent(html_43b62d0b03401a817bc5483b50ca24b4);
#
#
#
#         marker_a5351baf9787d9b72c2afe22c0bb37fc.bindPopup(popup_60b91a9246edab8c3f0e0bd999e33932)
#         ;
#
#
#
#
#             var marker_96365accd3765df90daf706aa123cb63 = L.marker(
#                 [47.3815542, 8.5095674],
#                 {}
#             ).addTo(map_fc1399c8a07567f01f01b94e1dbe2969);
#
#
#         var popup_d642439488052bae1b5822db424a0e27 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04bae62ff978ddac4ae44ca00fc15528 = $(`&lt;div id=&quot;html_04bae62ff978ddac4ae44ca00fc15528&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_d642439488052bae1b5822db424a0e27.setContent(html_04bae62ff978ddac4ae44ca00fc15528);
#
#
#
#         marker_96365accd3765df90daf706aa123cb63.bindPopup(popup_d642439488052bae1b5822db424a0e27)
#         ;
#
#
#
#
#             var marker_c15ee1b2713b66f186948b231e49c2f0 = L.marker(
#                 [47.3811098, 8.4921479],
#                 {}
#             ).addTo(map_fc1399c8a07567f01f01b94e1dbe2969);
#
#
#         var popup_d99c101b12bc3c3ceb411f9e0260a15e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c2dee621794620c6963691102825dcff = $(`&lt;div id=&quot;html_c2dee621794620c6963691102825dcff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migrol&lt;/div&gt;`)[0];
#                 popup_d99c101b12bc3c3ceb411f9e0260a15e.setContent(html_c2dee621794620c6963691102825dcff);
#
#
#
#         marker_c15ee1b2713b66f186948b231e49c2f0.bindPopup(popup_d99c101b12bc3c3ceb411f9e0260a15e)
#         ;
#
#
#
#
#             var marker_dba6f54721816df2e120278fb1ad4885 = L.marker(
#                 [47.3373646, 8.5301934],
#                 {}
#             ).addTo(map_fc1399c8a07567f01f01b94e1dbe2969);
#
#
#         var popup_824178d3eb174ec1768e60c9cefd43df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9f0ecab14929ea079db951237f87fcf2 = $(`&lt;div id=&quot;html_9f0ecab14929ea079db951237f87fcf2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_824178d3eb174ec1768e60c9cefd43df.setContent(html_9f0ecab14929ea079db951237f87fcf2);
#
#
#
#         marker_dba6f54721816df2e120278fb1ad4885.bindPopup(popup_824178d3eb174ec1768e60c9cefd43df)
#         ;
#
#
#
#
#             var marker_8eabc69042db9bffa457219a4eed9325 = L.marker(

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 10
# Datetime: 2023-03-09 09:32:07
# Python Version: 3.10.9
# -----------------------------------
